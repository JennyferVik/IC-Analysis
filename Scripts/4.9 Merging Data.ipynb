# %% [markdown]
# ### Importing libraries and Data

# %%
# Libraries
import pandas as pd
import numpy as np
import os

# %%
# Data
path = r'/Users/jennyfevik/Desktop/IC Basket Analysis'

# %%
df_ords_prods = pd.read_pickle(os.path.join(path, 'Data', 'Prepared', 'orders_products_ready.pkl'))

# %%
cust = pd.read_pickle(os.path.join(path, 'Data', 'Prepared', 'customers.pkl'))

# %%
# Checking data
df_ords_prods.shape
# Out:
# (32435070, 24)

# %%
df_ords_prods.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
#
#    ...    price_range_loc   busiest_day     busiest_days_2  \
# ...

# %%
cust.shape
# Out:
# (206209, 10)

# %%
cust.head()
# Out:
#    user_id first_name last_name  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# 2                  2    married   99568
# 3                  0     single   42049
# 4                  1    married   40374

# %% [markdown]
# ### Merging data

# %%
ic_data = df_ords_prods.merge(cust, on = ['user_id'], how = 'left')

# %%
ic_data.shape
# Out:
# (32435070, 33)

# %%
ic_data.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
#
# ...

# %%
ic_data.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243506e+07  3.243506e+07  3.243506e+07        3.243506e+07
# mean   1.710748e+06  1.029372e+05  1.714195e+01        2.738815e+00
# std    9.873006e+05  5.946651e+04  1.753496e+01        2.090051e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142000e+04  5.000000e+00        1.000000e+00
# 50%    1.711047e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243506e+07            3.035696e+07  3.243507e+07
# mean        1.342498e+01            1.110414e+01  2.557635e+04
# std         4.246357e+00            8.778941e+00  1.409657e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ### Exporting final merged data

# %%
ic_data.to_pickle(os.path.join(path, 'Data', 'Prepared', 'ic_data.pkl'))
