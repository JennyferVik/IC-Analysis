# %% [markdown]
# ### Importing

# %%
# Libraries
import pandas as pd
import numpy as np
import os

# %%
# Data
path = r'/Users/jennyfevik/Desktop/IC Basket Analysis'

# %%
cust = pd.read_csv(os.path.join(path, 'Data', 'Original', 'customers.csv'), index_col = False)

# %%
# Checking
cust.shape
# Out:
# (206209, 10)

# %%
cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# ### Renaming Columns

# %%
cust.rename(columns = {'Surnam' : 'last_name'}, inplace = True)

# %%
cust.rename(columns = {'n_dependants' : 'number_dependants'}, inplace = True)

# %%
cust.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
cust.head()
# Out:
#    user_id first_name last_name  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# 2                  2    married   99568
# 3                  0     single   42049
# 4                  1    married   40374

# %% [markdown]
# ### Checking consistency

# %%
cust.describe()
# Out:
#              user_id            Age  number_dependants         income
# count  206209.000000  206209.000000      206209.000000  206209.000000
# mean   103105.000000      49.501646           1.499823   94632.852548
# std     59527.555167      18.480962           1.118433   42473.786988
# min         1.000000      18.000000           0.000000   25903.000000
# 25%     51553.000000      33.000000           0.000000   59874.000000
# 50%    103105.000000      49.000000           1.000000   93547.000000
# 75%    154657.000000      66.000000           3.000000  124244.000000
# max    206209.000000      81.000000           3.000000  593901.000000

# %%
# Changing user_id to string
cust['user_id'] = cust['user_id'].astype('str')

# %%
cust['user_id'].dtype
# Out:
# dtype('O')

# %%
# Checking for mixed datatypes
for col in cust.columns.tolist():
    weird = (cust[[col]].applymap(type) !=cust[[col]].iloc[0].apply(type)).any(axis = 1)
    if len(cust[weird])>0:
        print(col)
# Out:
# first_name

# %% [markdown]
# ### Checking for missing values

# %%
cust.isnull().sum()
# Out:
# user_id                  0
# first_name           11259
# last_name                0
# Gender                   0
# STATE                    0
# Age                      0
# date_joined              0
# number_dependants        0
# fam_status               0
# income                   0
# dtype: int64

# %%
cust_nan = cust[cust['first_name'].isnull() == True]

# %%
cust_nan
# Out:
#        user_id first_name last_name  Gender         STATE  Age date_joined  \
# 53       76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73       13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82       89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99       96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105      29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...        ...        ...       ...     ...           ...  ...         ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044  200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090  167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162  187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171  116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         number_dependants fam_status  income
# ...

# %% [markdown]
# leaving missing first names as is, it doesn't affect the rest of the data

# %% [markdown]
# ### Checking for duplicates

# %%
cust_dup = cust[cust.duplicated()]

# %%
cust_dup
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, Gender, STATE, Age, date_joined, number_dependants, fam_status, income]
# Index: []

# %% [markdown]
# ### Re-checking data for anything missed

# %%
cust.describe()
# Out:
#                  Age  number_dependants         income
# count  206209.000000      206209.000000  206209.000000
# mean       49.501646           1.499823   94632.852548
# std        18.480962           1.118433   42473.786988
# min        18.000000           0.000000   25903.000000
# 25%        33.000000           0.000000   59874.000000
# 50%        49.000000           1.000000   93547.000000
# 75%        66.000000           3.000000  124244.000000
# max        81.000000           3.000000  593901.000000

# %%
cust.value_counts()
# Out:
# user_id  first_name   last_name  Gender  STATE         Age  date_joined  number_dependants  fam_status  income
# 1        Linda        Nguyen     Female  Alabama       31   2/17/2019    3                  married     40423     1
# 38163    Kenneth      Howe       Male    Indiana       30   2/26/2018    1                  married     54596     1
# 38154    Steve        Heath      Male    Colorado      74   8/13/2018    3                  married     148720    1
# 38155    Arthur       Quintana   Male    Connecticut   48   5/4/2017     0                  single      112955    1
# 38156    Annie        Gray       Female  Delaware      43   11/18/2017   2                  married     130009    1
#                                                                                                                  ..
# 161893   Nicholas     Wong       Male    Louisiana     69   3/11/2020    2                  married     145144    1
# ...

# %%
cust.shape
# Out:
# (206209, 10)

# %%
cust.head(30)
# Out:
#    user_id first_name  last_name  Gender           STATE  Age date_joined  \
# 0    26711    Deborah   Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia       Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth     Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle      Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann    Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia      Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris     Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph    Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy       Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn      Chung    Male        Virginia   26    1/1/2017
# 10   26441     Gloria   Stafford  Female          Nevada   19    1/1/2017
# 11   33835      Roger      Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            206209 non-null  object
#  1   first_name         194950 non-null  object
#  2   last_name          206209 non-null  object
#  3   Gender             206209 non-null  object
#  4   STATE              206209 non-null  object
#  5   Age                206209 non-null  int64
#  6   date_joined        206209 non-null  object
#  7   number_dependants  206209 non-null  int64
#  8   fam_status         206209 non-null  object
#  9   income             206209 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 15.7+ MB

# %% [markdown]
# ### Exporting Customer data

# %%
cust.to_csv(os.path.join(path, 'Data','Prepared', 'customers.csv'))
